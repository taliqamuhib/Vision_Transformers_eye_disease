# %%
# !pip install -U tensorflow-addons
import tensorflow_addons as tfa
import numpy as np
import tensorflow as tf
from sklearn.model_selection import train_test_split
from tensorflow import keras
from tensorflow.keras import layers
#import tensorflow_addons as tfa
import os
from tensorflow.keras.preprocessing.image import load_img
#from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.layers import AveragePooling2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Input
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.applications.mobilenet_v2 import preprocess_input
from tensorflow.keras.preprocessing.image import img_to_array
from tensorflow.keras.preprocessing.image import load_img
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
import numpy as np
import scipy.interpolate
import re
import matplotlib.pyplot as plt
import os

#from imutils import paths
from PIL import ImageFile
import pandas as pd
ImageFile.LOAD_TRUNCATED_IMAGES = True
# Out:
# Requirement already satisfied: tensorflow-addons in /opt/conda/lib/python3.10/site-packages (0.23.0)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.10/site-packages (from tensorflow-addons) (21.3)
# Requirement already satisfied: typeguard<3.0.0,>=2.7 in /opt/conda/lib/python3.10/site-packages (from tensorflow-addons) (2.13.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging->tensorflow-addons) (3.0.9)

# %%
dataset_path = os.listdir('/kaggle/input/new-eye-ds/Normal')


print (dataset_path)  #what kinds of classes are in this dataset

print("Types of classes labels found: ", len(dataset_path))
# Out:
# ['abnormalities', 'Diabetes', 'Hypertension', 'Glaucoma', 'Normal', 'Pathological Myopia', 'Age related Macular Degeneration', 'Cataract']
# Types of classes labels found:  8

# %%
import pandas as pd
class_labels = []

for item in dataset_path:
 # Get all the file names
 all_classes = os.listdir('/kaggle/input/new-eye-ds/Normal' + '/' +item)
 #print(all_classes)

# Add them to the list
 for room in all_classes:
    class_labels.append((item, str('dataset_path' + '/' +item) + '/' + room))
    #print(class_labels[:5])

# %%
# # Build a dataframe
df = pd.DataFrame(data=class_labels, columns=['Labels', 'image'])
print(df.head())
print(df.tail())
# Out:
#           Labels                                              image
# 0  abnormalities            dataset_path/abnormalities/660_left.jpg
# 1  abnormalities    dataset_path/abnormalities/901_right - Copy.jpg
# 2  abnormalities  dataset_path/abnormalities/928_left - Copy (2)...
# 3  abnormalities           dataset_path/abnormalities/357_right.jpg
# 4  abnormalities    dataset_path/abnormalities/523_right - Copy.jpg
#          Labels                                            image
# 18401  Cataract              dataset_path/Cataract/2105_left.jpg
# 18402  Cataract   dataset_path/Cataract/188_right - Copy (8).jpg
# 18403  Cataract  dataset_path/Cataract/2115_right - Copy (6).jpg
# 18404  Cataract              dataset_path/Cataract/2207_left.jpg
# 18405  Cataract  dataset_path/Cataract/2248_right - Copy (3).jpg

# %%
# Let's check how many samples for each category are present
print("Total number of images in the dataset: ", len(df))

label_count = df['Labels'].value_counts()
print(label_count)
# Out:
# Total number of images in the dataset:  18406
# Labels
# Normal                              2873
# Cataract                            2637
# Glaucoma                            2272
# Hypertension                        2160
# Age related Macular Degeneration    2128
# abnormalities                       2124
# Diabetes                            2124
# Pathological Myopia                 2088
# Name: count, dtype: int64

# %%
import os
import cv2
from PIL import Image
path = '/kaggle/input/new-eye-ds/Normal/'
dataset_path = os.listdir('/kaggle/input/new-eye-ds/Normal/')

im_size = 224
images = []
labels = []

for i in dataset_path:
    data_path = path + str(i)
    filenames = [i for i in os.listdir(data_path) ]

    for f in filenames:
        img = cv2.imread(data_path + '/' + f)
        img = cv2.resize(img, (im_size, im_size))
        #patches = extract_patches_2d(img, patch_size(224, 224), max_patches = 10)
        #img = np.array(img)
        images.append(img)
        labels.append(i)

# %%
images = np.array(images)

# %%
print(images.shape)
# Out:
# (18406, 224, 224, 3)

# %%
from sklearn.preprocessing import LabelEncoder , OneHotEncoder
y=df['Labels'].values
print(y)

y_labelencoder = LabelEncoder ()
y = y_labelencoder.fit_transform (y)
print (y)
# Out:
# ['abnormalities' 'abnormalities' 'abnormalities' ... 'Cataract' 'Cataract'
#  'Cataract']
# [7 7 7 ... 1 1 1]

# %%
y=y.reshape(-1,1)

from sklearn.compose import ColumnTransformer
ct = ColumnTransformer([('my_ohe', OneHotEncoder(), [0])], remainder='passthrough')
Y = ct.fit_transform(y) #.toarray()
print(Y[:5])
print(Y[35:])
# Out:
#   (0, 7)	1.0
#   (1, 7)	1.0
#   (2, 7)	1.0
#   (3, 7)	1.0
#   (4, 7)	1.0
#   (0, 7)	1.0
#   (1, 7)	1.0
#   (2, 7)	1.0
#   (3, 7)	1.0
#   (4, 7)	1.0
#   (5, 7)	1.0
#   (6, 7)	1.0
#   (7, 7)	1.0
#   (8, 7)	1.0
#   (9, 7)	1.0
#   (10, 7)	1.0
#   (11, 7)	1.0
#   (12, 7)	1.0
#   (13, 7)	1.0
#   (14, 7)	1.0
#   (15, 7)	1.0
#   (16, 7)	1.0
#   (17, 7)	1.0
#   (18, 7)	1.0
#   (19, 7)	1.0
#   (20, 7)	1.0
#   (21, 7)	1.0
#   (22, 7)	1.0
#   (23, 7)	1.0
#   (24, 7)	1.0
#   :	:
#   (18346, 1)	1.0
#   (18347, 1)	1.0
#   (18348, 1)	1.0
#   (18349, 1)	1.0
#   (18350, 1)	1.0
#   (18351, 1)	1.0
#   (18352, 1)	1.0
#   (18353, 1)	1.0
#   (18354, 1)	1.0
#   (18355, 1)	1.0
#   (18356, 1)	1.0
#   (18357, 1)	1.0
#   (18358, 1)	1.0
#   (18359, 1)	1.0
#   (18360, 1)	1.0
#   (18361, 1)	1.0
#   (18362, 1)	1.0
#   (18363, 1)	1.0
#   (18364, 1)	1.0
#   (18365, 1)	1.0
#   (18366, 1)	1.0
#   (18367, 1)	1.0
#   (18368, 1)	1.0
#   (18369, 1)	1.0
#   (18370, 1)	1.0

# %%
Y = Y.toarray() - 1
Y=(Y-1)
len(Y)
# Out:
# 18406

# %%
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split


images, Y = shuffle(images, Y, random_state=1)


train_x, test_x, train_y, test_y = train_test_split(images, Y, test_size=0.2, random_state=42)

# %%
print(f"x_train shape: {train_x.shape} - y_train shape: {train_y.shape}")
print(f"x_test shape: {test_x.shape} - y_test shape: {test_y.shape}")
# Out:
# x_train shape: (14724, 224, 224, 3) - y_train shape: (14724, 8)
# x_test shape: (3682, 224, 224, 3) - y_test shape: (3682, 8)

# %%
BUFFER_SIZE = 224
BATCH_SIZE = 256

# AUGMENTATION
IMAGE_SIZE = 224
PATCH_SIZE = 64
NUM_PATCHES = (IMAGE_SIZE // PATCH_SIZE) ** 2

# OPTIMIZER
LEARNING_RATE = 0.001
WEIGHT_DECAY = 0.0001

# TRAINING
EPOCHS = 50

# ARCHITECTURE
LAYER_NORM_EPS = 1e-6
TRANSFORMER_LAYERS = 8
PROJECTION_DIM = 64
NUM_HEADS = 4
TRANSFORMER_UNITS = [
    PROJECTION_DIM * 2,
    PROJECTION_DIM,
]
MLP_HEAD_UNITS = [2048, 1024]

# %%
from tensorflow import keras
data_augmentation =keras.Sequential(
    [
        keras.layers.Normalization(),
        keras.layers.Resizing(IMAGE_SIZE, IMAGE_SIZE),
        keras.layers.RandomFlip("horizontal"),
        keras.layers.RandomRotation(factor=0.02),
        keras.layers.RandomZoom(height_factor=0.2, width_factor=0.2),
    ],
    name="data_augmentation",
)
# Compute the mean and the variance of the training data for normalization.
data_augmentation.layers[0].adapt(train_x)

# %%
class ShiftedPatchTokenization(keras.layers.Layer):
    def __init__(
        self,
        image_size=IMAGE_SIZE,
        patch_size=PATCH_SIZE,
        num_patches=NUM_PATCHES,
        projection_dim=PROJECTION_DIM,
        vanilla=False,
        **kwargs,
    ):
        super().__init__(**kwargs)
        self.vanilla = vanilla  # Flag to swtich to vanilla patch extractor
        self.image_size = image_size
        self.patch_size = patch_size
        self.half_patch = patch_size // 2
        self.flatten_patches = keras.layers.Reshape((num_patches, -1))
        self.projection = keras.layers.Dense(units=projection_dim)
        self.layer_norm = keras.layers.LayerNormalization(epsilon=LAYER_NORM_EPS)

    def crop_shift_pad(self, images, mode):
        # Build the diagonally shifted images
        if mode == "left-up":
            crop_height = self.half_patch
            crop_width = self.half_patch
            shift_height = 0
            shift_width = 0
        elif mode == "left-down":
            crop_height = 0
            crop_width = self.half_patch
            shift_height = self.half_patch
            shift_width = 0
        elif mode == "right-up":
            crop_height = self.half_patch
            crop_width = 0
            shift_height = 0
            shift_width = self.half_patch
        else:
            crop_height = 0
            crop_width = 0
            shift_height = self.half_patch
            shift_width = self.half_patch

        # Crop the shifted images and pad them
        crop = tf.image.crop_to_bounding_box(
            images,
            offset_height=crop_height,
            offset_width=crop_width,
            target_height=self.image_size - self.half_patch,
            target_width=self.image_size - self.half_patch,
        )
        shift_pad = tf.image.pad_to_bounding_box(
            crop,
            offset_height=shift_height,
            offset_width=shift_width,
            target_height=self.image_size,
            target_width=self.image_size,
        )
        return shift_pad

    def call(self, images):
        if not self.vanilla:
            # Concat the shifted images with the original image
            images = tf.concat(
                [
                    images,
                    self.crop_shift_pad(images, mode="left-up"),
                    self.crop_shift_pad(images, mode="left-down"),
                    self.crop_shift_pad(images, mode="right-up"),
                    self.crop_shift_pad(images, mode="right-down"),
                ],
                axis=-1,
            )
        # Patchify the images and flatten it
        patches = tf.image.extract_patches(
            images=images,
            sizes=[1, self.patch_size, self.patch_size, 1],
            strides=[1, self.patch_size, self.patch_size, 1],
            rates=[1, 1, 1, 1],
            padding="VALID",
        )
        flat_patches = self.flatten_patches(patches)
        if not self.vanilla:
            # Layer normalize the flat patches and linearly project it
            tokens = self.layer_norm(flat_patches)
            tokens = self.projection(tokens)
        else:
            # Linearly project the flat patches
            tokens = self.projection(flat_patches)
        return (tokens, patches)

# %%
# Get a random image from the training dataset
# and resize the image
image = train_x[np.random.choice(range(train_x.shape[0]))]
resized_image = tf.image.resize(
    tf.convert_to_tensor([image]), size=(IMAGE_SIZE, IMAGE_SIZE)
)

# Vanilla patch maker: This takes an image and divides into
# patches as in the original ViT paper
(token, patch) = ShiftedPatchTokenization(vanilla=True)(resized_image / 255.0)
(token, patch) = (token[0], patch[0])
n = patch.shape[0]
count = 1
plt.figure(figsize=(4, 4))
for row in range(n):
    for col in range(n):
        plt.subplot(n, n, count)
        count = count + 1
        image = tf.reshape(patch[row][col], (PATCH_SIZE, PATCH_SIZE, 3))
        plt.imshow(image)
        plt.axis("off")
plt.show()

# Shifted Patch Tokenization: This layer takes the image, shifts it
# diagonally and then extracts patches from the concatinated images
(token, patch) = ShiftedPatchTokenization(vanilla=False)(resized_image / 255.0)
(token, patch) = (token[0], patch[0])
n = patch.shape[0]
shifted_images = ["ORIGINAL", "LEFT-UP", "LEFT-DOWN", "RIGHT-UP", "RIGHT-DOWN"]
for index, name in enumerate(shifted_images):
    print(name)
    count = 1
    plt.figure(figsize=(4, 4))
    for row in range(n):
        for col in range(n):
            plt.subplot(n, n, count)
            count = count + 1
            image = tf.reshape(patch[row][col], (PATCH_SIZE, PATCH_SIZE, 5 * 3))
            plt.imshow(image[..., 3 * index : 3 * index + 3])
            plt.axis("off")
    plt.show()
# Out:
# ORIGINAL
# LEFT-UP
# LEFT-DOWN
# RIGHT-UP
# RIGHT-DOWN

# %%
class PatchEncoder(layers.Layer):
    def __init__(
        self, num_patches=NUM_PATCHES, projection_dim=PROJECTION_DIM, **kwargs
    ):
        super().__init__(**kwargs)
        self.num_patches = num_patches
        self.position_embedding = layers.Embedding(
            input_dim=num_patches, output_dim=projection_dim
        )
        self.positions = tf.range(start=0, limit=self.num_patches, delta=1)

    def call(self, encoded_patches):
        encoded_positions = self.position_embedding(self.positions)
        encoded_patches = encoded_patches + encoded_positions
        return encoded_patches

# %%
class MultiHeadAttentionLSA(tf.keras.layers.MultiHeadAttention):
    def __init__(self, **kwargs):
        super().__init__(**kwargs)
        # The trainable temperature term. The initial value is
        # the square root of the key dimension.
        self.tau = tf.Variable(math.sqrt(float(self._key_dim)), trainable=True)

    def _compute_attention(self, query, key, value, attention_mask=None, training=None):
        query = tf.multiply(query, 1.0 / self.tau)
        attention_scores = tf.einsum(self._dot_product_equation, key, query)
        attention_scores = self._masked_softmax(attention_scores, attention_mask)
        attention_scores_dropout = self._dropout_layer(
            attention_scores, training=training
        )
        attention_output = tf.einsum(
            self._combine_equation, attention_scores_dropout, value
        )
        return attention_output, attention_scores

# %%
def mlp(x, hidden_units, dropout_rate):
    for units in hidden_units:
        x = layers.Dense(units, activation=tf.nn.gelu)(x)
        x = layers.Dropout(dropout_rate)(x)
    return x

# Build the diagonal attention mask
diag_attn_mask = 1 - tf.eye(NUM_PATCHES)
diag_attn_mask = tf.cast([diag_attn_mask], dtype=tf.int8)

# %%
INPUT_SHAPE = (224, 224, 3)
NUM_CLASSES = 8
def create_vit_classifier(vanilla=False):
    inputs = layers.Input(shape=INPUT_SHAPE)
    # Augment data.
    augmented = data_augmentation(inputs)
    # Create patches.
    (tokens, _) = ShiftedPatchTokenization(vanilla=vanilla)(augmented)
    # Encode patches.
    encoded_patches = PatchEncoder()(tokens)

    # Create multiple layers of the Transformer block.
    for _ in range(TRANSFORMER_LAYERS):
        # Layer normalization 1.
        x1 = layers.LayerNormalization(epsilon=1e-6)(encoded_patches)
        # Create a multi-head attention layer.
        if not vanilla:
            attention_output = MultiHeadAttentionLSA(
                num_heads=NUM_HEADS, key_dim=PROJECTION_DIM, dropout=0.1
            )(x1, x1, attention_mask=diag_attn_mask)
        else:
            attention_output = layers.MultiHeadAttention(
                num_heads=NUM_HEADS, key_dim=PROJECTION_DIM, dropout=0.1
            )(x1, x1)
        # Skip connection 1.
        x2 = layers.Add()([attention_output, encoded_patches])
        # Layer normalization 2.
        x3 = layers.LayerNormalization(epsilon=1e-6)(x2)
        # MLP.
        x3 = mlp(x3, hidden_units=TRANSFORMER_UNITS, dropout_rate=0.1)
        # Skip connection 2.
        encoded_patches = layers.Add()([x3, x2])

    # Create a [batch_size, projection_dim] tensor.
    representation = layers.LayerNormalization(epsilon=1e-6)(encoded_patches)
    representation = layers.Flatten()(representation)
    representation = layers.Dropout(0.5)(representation)
    # Add MLP.
    features = mlp(representation, hidden_units=MLP_HEAD_UNITS, dropout_rate=0.5)
    # Classify outputs.
    logits = layers.Dense(NUM_CLASSES)(features)
    # Create the Keras model.
    model = keras.Model(inputs=inputs, outputs=logits)
    return model

# %%
# Some code is taken from:
# https://www.kaggle.com/ashusma/training-rfcx-tensorflow-tpu-effnet-b2.


class WarmUpCosine(keras.optimizers.schedules.LearningRateSchedule):
    def __init__(
        self, learning_rate_base, total_steps, warmup_learning_rate, warmup_steps
    ):
        super(WarmUpCosine, self).__init__()

        self.learning_rate_base = learning_rate_base
        self.total_steps = total_steps
        self.warmup_learning_rate = warmup_learning_rate
        self.warmup_steps = warmup_steps
        self.pi = tf.constant(np.pi)

    def __call__(self, step):
        if self.total_steps < self.warmup_steps:
            raise ValueError("Total_steps must be larger or equal to warmup_steps.")

        cos_annealed_lr = tf.cos(
            self.pi
            * (tf.cast(step, tf.float32) - self.warmup_steps)
            / float(self.total_steps - self.warmup_steps)
        )
        learning_rate = 0.5 * self.learning_rate_base * (1 + cos_annealed_lr)

        if self.warmup_steps > 0:
            if self.learning_rate_base < self.warmup_learning_rate:
                raise ValueError(
                    "Learning_rate_base must be larger or equal to "
                    "warmup_learning_rate."
                )
            slope = (
                self.learning_rate_base - self.warmup_learning_rate
            ) / self.warmup_steps
            warmup_rate = slope * tf.cast(step, tf.float32) + self.warmup_learning_rate
            learning_rate = tf.where(
                step < self.warmup_steps, warmup_rate, learning_rate
            )
        return tf.where(
            step > self.total_steps, 0.0, learning_rate, name="learning_rate"
        )


def run_experiment(model):
    total_steps = int((len(train_x) / BATCH_SIZE) * EPOCHS)
    warmup_epoch_percentage = 0.10
    warmup_steps = int(total_steps * warmup_epoch_percentage)
    scheduled_lrs = WarmUpCosine(
        learning_rate_base=LEARNING_RATE,
        total_steps=total_steps,
        warmup_learning_rate=0.001,
        warmup_steps=warmup_steps,
    )

    optimizer = tfa.optimizers.AdamW(
        learning_rate=LEARNING_RATE, weight_decay=WEIGHT_DECAY
    )
    model.compile(
        optimizer=optimizer,
        loss=tf.keras.losses.MeanSquaredError(),
        metrics=['accuracy']
    )

    history = model.fit(
        x=train_x,
        y=train_y,
        batch_size=BATCH_SIZE,
        epochs=350,
        validation_split=0.1,
    )

    # Extract training accuracy values from the history
    training_accuracy = history.history['accuracy']
    validation_accuracy = history.history['val_accuracy']  # If validation accuracy is available

    # Display overall accuracy
    plt.plot(training_accuracy, label='Training Accuracy')
    if 'val_accuracy' in history.history:
        plt.plot(validation_accuracy, label='Validation Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.title('Overall Accuracy')
    plt.show()

    return history

# ... (existing code)

# Run experiments with the vanilla ViT
vit = create_vit_classifier(vanilla=True)
history = run_experiment(vit)

# Run experiments with the Shifted Patch Tokenization and
# Locality Self Attention modified ViT
# vit_sl = create_vit_classifier(vanilla=False)
# history = run_experiment(vit_sl)
# Out:
# Epoch 1/350
# 52/52 [==============================] - 18s 103ms/step - loss: 0.6890 - accuracy: 0.1401 - val_loss: 1.0285 - val_accuracy: 0.1948
# Epoch 2/350
# 52/52 [==============================] - 4s 72ms/step - loss: 0.2396 - accuracy: 0.1549 - val_loss: 1.0803 - val_accuracy: 0.1684
# Epoch 3/350
# 52/52 [==============================] - 4s 72ms/step - loss: 0.1889 - accuracy: 0.1598 - val_loss: 0.9510 - val_accuracy: 0.1697
# Epoch 4/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.1671 - accuracy: 0.1690 - val_loss: 0.6554 - val_accuracy: 0.1738
# Epoch 5/350
# 52/52 [==============================] - 4s 72ms/step - loss: 0.1560 - accuracy: 0.1641 - val_loss: 0.5735 - val_accuracy: 0.2247
# Epoch 6/350
# 52/52 [==============================] - 4s 72ms/step - loss: 0.1487 - accuracy: 0.1794 - val_loss: 0.4547 - val_accuracy: 0.1881
# Epoch 7/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.1430 - accuracy: 0.1793 - val_loss: 0.3103 - val_accuracy: 0.2437
# Epoch 8/350
# 52/52 [==============================] - 4s 75ms/step - loss: 0.1379 - accuracy: 0.1941 - val_loss: 0.2161 - val_accuracy: 0.2749
# Epoch 9/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.1341 - accuracy: 0.2002 - val_loss: 0.1500 - val_accuracy: 0.2743
# Epoch 10/350
# 52/52 [==============================] - 4s 72ms/step - loss: 0.1299 - accuracy: 0.2067 - val_loss: 0.1561 - val_accuracy: 0.2858
# Epoch 11/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.1269 - accuracy: 0.2204 - val_loss: 0.1320 - val_accuracy: 0.2974
# Epoch 12/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.1242 - accuracy: 0.2247 - val_loss: 0.1105 - val_accuracy: 0.2851
# Epoch 13/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.1215 - accuracy: 0.2392 - val_loss: 0.1117 - val_accuracy: 0.3116
# Epoch 14/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.1198 - accuracy: 0.2339 - val_loss: 0.1056 - val_accuracy: 0.3136
# Epoch 15/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.1179 - accuracy: 0.2487 - val_loss: 0.1068 - val_accuracy: 0.3028
# Epoch 16/350
# 52/52 [==============================] - 4s 75ms/step - loss: 0.1158 - accuracy: 0.2605 - val_loss: 0.1037 - val_accuracy: 0.3150
# Epoch 17/350
# 52/52 [==============================] - 4s 74ms/step - loss: 0.1148 - accuracy: 0.2654 - val_loss: 0.1012 - val_accuracy: 0.3279
# Epoch 18/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.1137 - accuracy: 0.2684 - val_loss: 0.1008 - val_accuracy: 0.3150
# Epoch 19/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.1122 - accuracy: 0.2779 - val_loss: 0.1000 - val_accuracy: 0.3170
# Epoch 20/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.1111 - accuracy: 0.2865 - val_loss: 0.0997 - val_accuracy: 0.3442
# Epoch 21/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.1104 - accuracy: 0.2857 - val_loss: 0.0985 - val_accuracy: 0.3327
# Epoch 22/350
# 52/52 [==============================] - 4s 74ms/step - loss: 0.1092 - accuracy: 0.2988 - val_loss: 0.0979 - val_accuracy: 0.3428
# Epoch 23/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.1086 - accuracy: 0.2997 - val_loss: 0.0975 - val_accuracy: 0.3700
# Epoch 24/350
# 52/52 [==============================] - 4s 75ms/step - loss: 0.1075 - accuracy: 0.3055 - val_loss: 0.0968 - val_accuracy: 0.3503
# Epoch 25/350
# 52/52 [==============================] - 4s 74ms/step - loss: 0.1065 - accuracy: 0.3106 - val_loss: 0.0973 - val_accuracy: 0.3476
# Epoch 26/350
# 52/52 [==============================] - 4s 72ms/step - loss: 0.1057 - accuracy: 0.3134 - val_loss: 0.0964 - val_accuracy: 0.3720
# Epoch 27/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.1050 - accuracy: 0.3230 - val_loss: 0.0954 - val_accuracy: 0.3700
# Epoch 28/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.1043 - accuracy: 0.3296 - val_loss: 0.0974 - val_accuracy: 0.3686
# Epoch 29/350
# 52/52 [==============================] - 4s 72ms/step - loss: 0.1036 - accuracy: 0.3340 - val_loss: 0.0934 - val_accuracy: 0.3788
# Epoch 30/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.1025 - accuracy: 0.3467 - val_loss: 0.0951 - val_accuracy: 0.3863
# Epoch 31/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.1019 - accuracy: 0.3471 - val_loss: 0.0931 - val_accuracy: 0.4039
# Epoch 32/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.1013 - accuracy: 0.3517 - val_loss: 0.0933 - val_accuracy: 0.4012
# Epoch 33/350
# 52/52 [==============================] - 4s 74ms/step - loss: 0.1004 - accuracy: 0.3607 - val_loss: 0.0942 - val_accuracy: 0.3944
# Epoch 34/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0998 - accuracy: 0.3621 - val_loss: 0.0922 - val_accuracy: 0.4134
# Epoch 35/350
# 52/52 [==============================] - 4s 72ms/step - loss: 0.0995 - accuracy: 0.3711 - val_loss: 0.0922 - val_accuracy: 0.4121
# Epoch 36/350
# 52/52 [==============================] - 4s 72ms/step - loss: 0.0987 - accuracy: 0.3816 - val_loss: 0.0911 - val_accuracy: 0.4073
# Epoch 37/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0979 - accuracy: 0.3803 - val_loss: 0.0892 - val_accuracy: 0.4325
# Epoch 38/350
# 52/52 [==============================] - 4s 72ms/step - loss: 0.0973 - accuracy: 0.3922 - val_loss: 0.0919 - val_accuracy: 0.4270
# Epoch 39/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0968 - accuracy: 0.3920 - val_loss: 0.0915 - val_accuracy: 0.4460
# Epoch 40/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0960 - accuracy: 0.4010 - val_loss: 0.0880 - val_accuracy: 0.4426
# Epoch 41/350
# 52/52 [==============================] - 4s 75ms/step - loss: 0.0953 - accuracy: 0.4024 - val_loss: 0.0892 - val_accuracy: 0.4603
# Epoch 42/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0949 - accuracy: 0.4114 - val_loss: 0.0919 - val_accuracy: 0.4223
# Epoch 43/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0942 - accuracy: 0.4109 - val_loss: 0.0874 - val_accuracy: 0.4501
# Epoch 44/350
# 52/52 [==============================] - 4s 74ms/step - loss: 0.0941 - accuracy: 0.4104 - val_loss: 0.0857 - val_accuracy: 0.4637
# Epoch 45/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0936 - accuracy: 0.4179 - val_loss: 0.0854 - val_accuracy: 0.4603
# Epoch 46/350
# 52/52 [==============================] - 4s 74ms/step - loss: 0.0923 - accuracy: 0.4268 - val_loss: 0.0856 - val_accuracy: 0.4881
# Epoch 48/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0918 - accuracy: 0.4320 - val_loss: 0.0839 - val_accuracy: 0.4827
# Epoch 49/350
# 52/52 [==============================] - 4s 75ms/step - loss: 0.0911 - accuracy: 0.4358 - val_loss: 0.0902 - val_accuracy: 0.4528
# Epoch 50/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0905 - accuracy: 0.4409 - val_loss: 0.0836 - val_accuracy: 0.4698
# Epoch 51/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0900 - accuracy: 0.4458 - val_loss: 0.0837 - val_accuracy: 0.4895
# Epoch 52/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0900 - accuracy: 0.4468 - val_loss: 0.0843 - val_accuracy: 0.4969
# Epoch 53/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0891 - accuracy: 0.4541 - val_loss: 0.0834 - val_accuracy: 0.4915
# Epoch 54/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0885 - accuracy: 0.4545 - val_loss: 0.0808 - val_accuracy: 0.4969
# Epoch 55/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0879 - accuracy: 0.4572 - val_loss: 0.0811 - val_accuracy: 0.4888
# Epoch 56/350
# 52/52 [==============================] - 4s 72ms/step - loss: 0.0880 - accuracy: 0.4628 - val_loss: 0.0794 - val_accuracy: 0.4936
# Epoch 57/350
# 52/52 [==============================] - 4s 74ms/step - loss: 0.0875 - accuracy: 0.4665 - val_loss: 0.0797 - val_accuracy: 0.5153
# Epoch 58/350
# 52/52 [==============================] - 4s 72ms/step - loss: 0.0873 - accuracy: 0.4632 - val_loss: 0.0820 - val_accuracy: 0.4881
# Epoch 59/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0866 - accuracy: 0.4751 - val_loss: 0.0803 - val_accuracy: 0.4902
# Epoch 60/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0859 - accuracy: 0.4766 - val_loss: 0.0803 - val_accuracy: 0.5139
# Epoch 61/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0862 - accuracy: 0.4748 - val_loss: 0.0784 - val_accuracy: 0.5187
# Epoch 62/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0857 - accuracy: 0.4767 - val_loss: 0.0775 - val_accuracy: 0.5173
# Epoch 63/350
# 52/52 [==============================] - 4s 72ms/step - loss: 0.0854 - accuracy: 0.4809 - val_loss: 0.0777 - val_accuracy: 0.5058
# Epoch 64/350
# 52/52 [==============================] - 4s 74ms/step - loss: 0.0849 - accuracy: 0.4807 - val_loss: 0.0765 - val_accuracy: 0.5234
# Epoch 65/350
# 52/52 [==============================] - 4s 75ms/step - loss: 0.0845 - accuracy: 0.4862 - val_loss: 0.0757 - val_accuracy: 0.5234
# Epoch 66/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0841 - accuracy: 0.4929 - val_loss: 0.0783 - val_accuracy: 0.5132
# Epoch 67/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0839 - accuracy: 0.4933 - val_loss: 0.0761 - val_accuracy: 0.5282
# Epoch 68/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0830 - accuracy: 0.4989 - val_loss: 0.0766 - val_accuracy: 0.5112
# Epoch 69/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0830 - accuracy: 0.4954 - val_loss: 0.0737 - val_accuracy: 0.5336
# Epoch 70/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0823 - accuracy: 0.5045 - val_loss: 0.0735 - val_accuracy: 0.5343
# Epoch 71/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0824 - accuracy: 0.4993 - val_loss: 0.0754 - val_accuracy: 0.5221
# Epoch 72/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0824 - accuracy: 0.5001 - val_loss: 0.0723 - val_accuracy: 0.5445
# Epoch 73/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0819 - accuracy: 0.5047 - val_loss: 0.0719 - val_accuracy: 0.5451
# Epoch 74/350
# 52/52 [==============================] - 4s 75ms/step - loss: 0.0818 - accuracy: 0.5093 - val_loss: 0.0764 - val_accuracy: 0.5404
# Epoch 75/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0814 - accuracy: 0.5136 - val_loss: 0.0727 - val_accuracy: 0.5472
# Epoch 76/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0813 - accuracy: 0.5119 - val_loss: 0.0711 - val_accuracy: 0.5485
# Epoch 77/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0803 - accuracy: 0.5181 - val_loss: 0.0736 - val_accuracy: 0.5234
# Epoch 78/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0805 - accuracy: 0.5173 - val_loss: 0.0728 - val_accuracy: 0.5526
# Epoch 79/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0795 - accuracy: 0.5261 - val_loss: 0.0707 - val_accuracy: 0.5580
# Epoch 80/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0788 - accuracy: 0.5277 - val_loss: 0.0725 - val_accuracy: 0.5485
# Epoch 81/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0792 - accuracy: 0.5259 - val_loss: 0.0690 - val_accuracy: 0.5438
# Epoch 82/350
# 52/52 [==============================] - 4s 74ms/step - loss: 0.0790 - accuracy: 0.5269 - val_loss: 0.0711 - val_accuracy: 0.5458
# Epoch 83/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0791 - accuracy: 0.5286 - val_loss: 0.0688 - val_accuracy: 0.5594
# Epoch 84/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0795 - accuracy: 0.5243 - val_loss: 0.0691 - val_accuracy: 0.5533
# Epoch 85/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0779 - accuracy: 0.5406 - val_loss: 0.0692 - val_accuracy: 0.5547
# Epoch 86/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0780 - accuracy: 0.5377 - val_loss: 0.0691 - val_accuracy: 0.5662
# Epoch 87/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0771 - accuracy: 0.5411 - val_loss: 0.0673 - val_accuracy: 0.5594
# Epoch 88/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0774 - accuracy: 0.5428 - val_loss: 0.0678 - val_accuracy: 0.5757
# Epoch 89/350
# 52/52 [==============================] - 4s 72ms/step - loss: 0.0778 - accuracy: 0.5406 - val_loss: 0.0671 - val_accuracy: 0.5730
# Epoch 90/350
# 52/52 [==============================] - 4s 75ms/step - loss: 0.0762 - accuracy: 0.5468 - val_loss: 0.0668 - val_accuracy: 0.5743
# Epoch 91/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0763 - accuracy: 0.5469 - val_loss: 0.0687 - val_accuracy: 0.5689
# Epoch 92/350
# 52/52 [==============================] - 4s 72ms/step - loss: 0.0771 - accuracy: 0.5403 - val_loss: 0.0656 - val_accuracy: 0.5879
# Epoch 93/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0757 - accuracy: 0.5509 - val_loss: 0.0663 - val_accuracy: 0.5866
# Epoch 94/350
# 52/52 [==============================] - 4s 72ms/step - loss: 0.0755 - accuracy: 0.5569 - val_loss: 0.0662 - val_accuracy: 0.5777
# Epoch 95/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0754 - accuracy: 0.5539 - val_loss: 0.0654 - val_accuracy: 0.5879
# Epoch 96/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0748 - accuracy: 0.5614 - val_loss: 0.0634 - val_accuracy: 0.5818
# Epoch 97/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0752 - accuracy: 0.5600 - val_loss: 0.0639 - val_accuracy: 0.5852
# Epoch 98/350
# 52/52 [==============================] - 4s 75ms/step - loss: 0.0745 - accuracy: 0.5613 - val_loss: 0.0669 - val_accuracy: 0.5832
# Epoch 99/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0744 - accuracy: 0.5663 - val_loss: 0.0642 - val_accuracy: 0.5947
# Epoch 100/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0742 - accuracy: 0.5635 - val_loss: 0.0648 - val_accuracy: 0.5737
# Epoch 101/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0740 - accuracy: 0.5666 - val_loss: 0.0635 - val_accuracy: 0.5852
# Epoch 102/350
# 52/52 [==============================] - 4s 72ms/step - loss: 0.0743 - accuracy: 0.5606 - val_loss: 0.0628 - val_accuracy: 0.5893
# Epoch 103/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0738 - accuracy: 0.5710 - val_loss: 0.0636 - val_accuracy: 0.5988
# Epoch 104/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0734 - accuracy: 0.5692 - val_loss: 0.0631 - val_accuracy: 0.6029
# Epoch 105/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0728 - accuracy: 0.5816 - val_loss: 0.0612 - val_accuracy: 0.5947
# Epoch 106/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0727 - accuracy: 0.5742 - val_loss: 0.0639 - val_accuracy: 0.5906
# Epoch 107/350
# 52/52 [==============================] - 4s 74ms/step - loss: 0.0726 - accuracy: 0.5766 - val_loss: 0.0624 - val_accuracy: 0.6001
# Epoch 108/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0729 - accuracy: 0.5763 - val_loss: 0.0666 - val_accuracy: 0.5791
# Epoch 109/350
# 52/52 [==============================] - 4s 74ms/step - loss: 0.0725 - accuracy: 0.5763 - val_loss: 0.0623 - val_accuracy: 0.6035
# Epoch 110/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0719 - accuracy: 0.5885 - val_loss: 0.0623 - val_accuracy: 0.6076
# Epoch 111/350
# 52/52 [==============================] - 4s 72ms/step - loss: 0.0717 - accuracy: 0.5890 - val_loss: 0.0619 - val_accuracy: 0.6171
# Epoch 112/350
# 52/52 [==============================] - 4s 74ms/step - loss: 0.0713 - accuracy: 0.5901 - val_loss: 0.0633 - val_accuracy: 0.6035
# Epoch 113/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0713 - accuracy: 0.5869 - val_loss: 0.0614 - val_accuracy: 0.6151
# Epoch 114/350
# 52/52 [==============================] - 4s 72ms/step - loss: 0.0707 - accuracy: 0.5926 - val_loss: 0.0619 - val_accuracy: 0.6164
# Epoch 115/350
# 52/52 [==============================] - 4s 75ms/step - loss: 0.0720 - accuracy: 0.5834 - val_loss: 0.0629 - val_accuracy: 0.6090
# Epoch 116/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0717 - accuracy: 0.5858 - val_loss: 0.0620 - val_accuracy: 0.6144
# Epoch 117/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0699 - accuracy: 0.5970 - val_loss: 0.0620 - val_accuracy: 0.6164
# Epoch 118/350
# 52/52 [==============================] - 4s 72ms/step - loss: 0.0707 - accuracy: 0.5933 - val_loss: 0.0605 - val_accuracy: 0.6246
# Epoch 119/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0698 - accuracy: 0.5986 - val_loss: 0.0580 - val_accuracy: 0.6280
# Epoch 120/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0698 - accuracy: 0.6009 - val_loss: 0.0597 - val_accuracy: 0.6293
# Epoch 121/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0698 - accuracy: 0.5994 - val_loss: 0.0592 - val_accuracy: 0.6286
# Epoch 122/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0695 - accuracy: 0.5996 - val_loss: 0.0596 - val_accuracy: 0.6253
# Epoch 123/350
# 52/52 [==============================] - 4s 75ms/step - loss: 0.0690 - accuracy: 0.6095 - val_loss: 0.0613 - val_accuracy: 0.6178
# Epoch 124/350
# 52/52 [==============================] - 4s 72ms/step - loss: 0.0688 - accuracy: 0.6096 - val_loss: 0.0596 - val_accuracy: 0.6246
# Epoch 125/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0691 - accuracy: 0.6075 - val_loss: 0.0596 - val_accuracy: 0.6259
# Epoch 126/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0687 - accuracy: 0.6042 - val_loss: 0.0579 - val_accuracy: 0.6483
# Epoch 127/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0690 - accuracy: 0.6061 - val_loss: 0.0580 - val_accuracy: 0.6483
# Epoch 128/350
# 52/52 [==============================] - 4s 74ms/step - loss: 0.0686 - accuracy: 0.6141 - val_loss: 0.0581 - val_accuracy: 0.6538
# Epoch 129/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0676 - accuracy: 0.6216 - val_loss: 0.0564 - val_accuracy: 0.6409
# Epoch 130/350
# 52/52 [==============================] - 4s 72ms/step - loss: 0.0679 - accuracy: 0.6176 - val_loss: 0.0582 - val_accuracy: 0.6320
# Epoch 131/350
# 52/52 [==============================] - 4s 75ms/step - loss: 0.0675 - accuracy: 0.6192 - val_loss: 0.0567 - val_accuracy: 0.6517
# Epoch 132/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0672 - accuracy: 0.6253 - val_loss: 0.0584 - val_accuracy: 0.6422
# Epoch 133/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0671 - accuracy: 0.6224 - val_loss: 0.0570 - val_accuracy: 0.6470
# Epoch 134/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0670 - accuracy: 0.6252 - val_loss: 0.0588 - val_accuracy: 0.6395
# Epoch 135/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0667 - accuracy: 0.6222 - val_loss: 0.0586 - val_accuracy: 0.6470
# Epoch 136/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0671 - accuracy: 0.6212 - val_loss: 0.0567 - val_accuracy: 0.6436
# Epoch 137/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0665 - accuracy: 0.6286 - val_loss: 0.0563 - val_accuracy: 0.6585
# Epoch 138/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0660 - accuracy: 0.6283 - val_loss: 0.0565 - val_accuracy: 0.6578
# Epoch 139/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0660 - accuracy: 0.6267 - val_loss: 0.0550 - val_accuracy: 0.6619
# Epoch 140/350
# 52/52 [==============================] - 4s 74ms/step - loss: 0.0660 - accuracy: 0.6313 - val_loss: 0.0582 - val_accuracy: 0.6354
# Epoch 141/350
# 52/52 [==============================] - 4s 74ms/step - loss: 0.0661 - accuracy: 0.6299 - val_loss: 0.0561 - val_accuracy: 0.6504
# Epoch 142/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0661 - accuracy: 0.6292 - val_loss: 0.0573 - val_accuracy: 0.6443
# Epoch 143/350
# 52/52 [==============================] - 4s 75ms/step - loss: 0.0664 - accuracy: 0.6282 - val_loss: 0.0543 - val_accuracy: 0.6755
# Epoch 144/350
# 52/52 [==============================] - 4s 72ms/step - loss: 0.0651 - accuracy: 0.6360 - val_loss: 0.0558 - val_accuracy: 0.6640
# Epoch 145/350
# 52/52 [==============================] - 4s 74ms/step - loss: 0.0655 - accuracy: 0.6339 - val_loss: 0.0551 - val_accuracy: 0.6775
# Epoch 146/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0654 - accuracy: 0.6390 - val_loss: 0.0552 - val_accuracy: 0.6694
# Epoch 147/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0653 - accuracy: 0.6360 - val_loss: 0.0551 - val_accuracy: 0.6538
# Epoch 148/350
# 52/52 [==============================] - 4s 74ms/step - loss: 0.0646 - accuracy: 0.6452 - val_loss: 0.0546 - val_accuracy: 0.6741
# Epoch 149/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0644 - accuracy: 0.6419 - val_loss: 0.0589 - val_accuracy: 0.6449
# Epoch 150/350
# 52/52 [==============================] - 4s 72ms/step - loss: 0.0654 - accuracy: 0.6334 - val_loss: 0.0555 - val_accuracy: 0.6680
# Epoch 151/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0645 - accuracy: 0.6430 - val_loss: 0.0538 - val_accuracy: 0.6653
# Epoch 152/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0649 - accuracy: 0.6450 - val_loss: 0.0541 - val_accuracy: 0.6572
# Epoch 153/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0645 - accuracy: 0.6444 - val_loss: 0.0555 - val_accuracy: 0.6775
# Epoch 154/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0637 - accuracy: 0.6444 - val_loss: 0.0535 - val_accuracy: 0.6687
# Epoch 155/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0640 - accuracy: 0.6480 - val_loss: 0.0543 - val_accuracy: 0.6660
# Epoch 156/350
# 52/52 [==============================] - 4s 75ms/step - loss: 0.0636 - accuracy: 0.6520 - val_loss: 0.0550 - val_accuracy: 0.6755
# Epoch 157/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0639 - accuracy: 0.6448 - val_loss: 0.0555 - val_accuracy: 0.6612
# Epoch 158/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0640 - accuracy: 0.6462 - val_loss: 0.0577 - val_accuracy: 0.6701
# Epoch 159/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0631 - accuracy: 0.6553 - val_loss: 0.0542 - val_accuracy: 0.6694
# Epoch 160/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0626 - accuracy: 0.6594 - val_loss: 0.0538 - val_accuracy: 0.6714
# Epoch 161/350
# 52/52 [==============================] - 4s 74ms/step - loss: 0.0627 - accuracy: 0.6560 - val_loss: 0.0527 - val_accuracy: 0.6741
# Epoch 162/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0632 - accuracy: 0.6519 - val_loss: 0.0526 - val_accuracy: 0.6728
# Epoch 163/350
# 52/52 [==============================] - 4s 72ms/step - loss: 0.0623 - accuracy: 0.6567 - val_loss: 0.0545 - val_accuracy: 0.6768
# Epoch 164/350
# 52/52 [==============================] - 4s 74ms/step - loss: 0.0626 - accuracy: 0.6537 - val_loss: 0.0538 - val_accuracy: 0.6755
# Epoch 165/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0624 - accuracy: 0.6608 - val_loss: 0.0558 - val_accuracy: 0.6701
# Epoch 166/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0623 - accuracy: 0.6622 - val_loss: 0.0525 - val_accuracy: 0.6748
# Epoch 167/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0618 - accuracy: 0.6655 - val_loss: 0.0509 - val_accuracy: 0.6891
# Epoch 168/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0613 - accuracy: 0.6644 - val_loss: 0.0533 - val_accuracy: 0.6802
# Epoch 169/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0618 - accuracy: 0.6652 - val_loss: 0.0532 - val_accuracy: 0.6823
# Epoch 170/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0611 - accuracy: 0.6686 - val_loss: 0.0526 - val_accuracy: 0.6782
# Epoch 171/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0612 - accuracy: 0.6680 - val_loss: 0.0534 - val_accuracy: 0.6789
# Epoch 172/350
# 52/52 [==============================] - 4s 74ms/step - loss: 0.0615 - accuracy: 0.6667 - val_loss: 0.0519 - val_accuracy: 0.6870
# Epoch 173/350
# 52/52 [==============================] - 4s 74ms/step - loss: 0.0608 - accuracy: 0.6717 - val_loss: 0.0533 - val_accuracy: 0.6897
# Epoch 174/350
# 52/52 [==============================] - 4s 72ms/step - loss: 0.0609 - accuracy: 0.6679 - val_loss: 0.0528 - val_accuracy: 0.6836
# Epoch 175/350
# 52/52 [==============================] - 4s 74ms/step - loss: 0.0607 - accuracy: 0.6753 - val_loss: 0.0533 - val_accuracy: 0.6918
# Epoch 176/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0612 - accuracy: 0.6670 - val_loss: 0.0526 - val_accuracy: 0.6884
# Epoch 177/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0607 - accuracy: 0.6713 - val_loss: 0.0517 - val_accuracy: 0.6884
# Epoch 178/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0602 - accuracy: 0.6754 - val_loss: 0.0518 - val_accuracy: 0.6952
# Epoch 179/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0598 - accuracy: 0.6784 - val_loss: 0.0511 - val_accuracy: 0.6931
# Epoch 180/350
# 52/52 [==============================] - 4s 74ms/step - loss: 0.0603 - accuracy: 0.6777 - val_loss: 0.0495 - val_accuracy: 0.6938
# Epoch 181/350
# 52/52 [==============================] - 4s 74ms/step - loss: 0.0592 - accuracy: 0.6830 - val_loss: 0.0523 - val_accuracy: 0.6870
# Epoch 182/350
# 52/52 [==============================] - 4s 72ms/step - loss: 0.0599 - accuracy: 0.6792 - val_loss: 0.0502 - val_accuracy: 0.7060
# Epoch 183/350
# 52/52 [==============================] - 4s 74ms/step - loss: 0.0594 - accuracy: 0.6803 - val_loss: 0.0501 - val_accuracy: 0.7013
# Epoch 184/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0599 - accuracy: 0.6778 - val_loss: 0.0532 - val_accuracy: 0.6843
# Epoch 185/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0590 - accuracy: 0.6855 - val_loss: 0.0520 - val_accuracy: 0.6972
# Epoch 186/350
# 52/52 [==============================] - 4s 72ms/step - loss: 0.0594 - accuracy: 0.6799 - val_loss: 0.0513 - val_accuracy: 0.6870
# Epoch 187/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0590 - accuracy: 0.6872 - val_loss: 0.0541 - val_accuracy: 0.6843
# Epoch 188/350
# 52/52 [==============================] - 4s 74ms/step - loss: 0.0592 - accuracy: 0.6839 - val_loss: 0.0503 - val_accuracy: 0.6918
# Epoch 189/350
# 52/52 [==============================] - 4s 75ms/step - loss: 0.0584 - accuracy: 0.6873 - val_loss: 0.0509 - val_accuracy: 0.7006
# Epoch 190/350
# 52/52 [==============================] - 4s 72ms/step - loss: 0.0585 - accuracy: 0.6914 - val_loss: 0.0524 - val_accuracy: 0.7026
# Epoch 191/350
# 52/52 [==============================] - 4s 74ms/step - loss: 0.0582 - accuracy: 0.6888 - val_loss: 0.0516 - val_accuracy: 0.6816
# Epoch 192/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0585 - accuracy: 0.6889 - val_loss: 0.0501 - val_accuracy: 0.7020
# Epoch 193/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0588 - accuracy: 0.6849 - val_loss: 0.0490 - val_accuracy: 0.6965
# Epoch 194/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0584 - accuracy: 0.6911 - val_loss: 0.0498 - val_accuracy: 0.7115
# Epoch 195/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0581 - accuracy: 0.6924 - val_loss: 0.0511 - val_accuracy: 0.7094
# Epoch 196/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0579 - accuracy: 0.6894 - val_loss: 0.0488 - val_accuracy: 0.7081
# Epoch 197/350
# 52/52 [==============================] - 4s 75ms/step - loss: 0.0580 - accuracy: 0.6908 - val_loss: 0.0502 - val_accuracy: 0.6972
# Epoch 198/350
# 52/52 [==============================] - 4s 72ms/step - loss: 0.0575 - accuracy: 0.6974 - val_loss: 0.0482 - val_accuracy: 0.7162
# Epoch 199/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0579 - accuracy: 0.6933 - val_loss: 0.0489 - val_accuracy: 0.7054
# Epoch 200/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0574 - accuracy: 0.6938 - val_loss: 0.0495 - val_accuracy: 0.7115
# Epoch 201/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0576 - accuracy: 0.6972 - val_loss: 0.0488 - val_accuracy: 0.7040
# Epoch 202/350
# 52/52 [==============================] - 4s 72ms/step - loss: 0.0572 - accuracy: 0.6984 - val_loss: 0.0490 - val_accuracy: 0.7176
# Epoch 203/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0569 - accuracy: 0.6996 - val_loss: 0.0490 - val_accuracy: 0.7162
# Epoch 204/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0568 - accuracy: 0.6987 - val_loss: 0.0503 - val_accuracy: 0.7149
# Epoch 205/350
# 52/52 [==============================] - 4s 74ms/step - loss: 0.0563 - accuracy: 0.7022 - val_loss: 0.0509 - val_accuracy: 0.6823
# Epoch 206/350
# 52/52 [==============================] - 4s 74ms/step - loss: 0.0563 - accuracy: 0.7022 - val_loss: 0.0509 - val_accuracy: 0.7033
# Epoch 207/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0564 - accuracy: 0.7030 - val_loss: 0.0474 - val_accuracy: 0.7203
# Epoch 208/350
# 52/52 [==============================] - 4s 74ms/step - loss: 0.0567 - accuracy: 0.7014 - val_loss: 0.0499 - val_accuracy: 0.7040
# Epoch 209/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0564 - accuracy: 0.7036 - val_loss: 0.0487 - val_accuracy: 0.7074
# Epoch 210/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0560 - accuracy: 0.7073 - val_loss: 0.0482 - val_accuracy: 0.7162
# Epoch 211/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0557 - accuracy: 0.7101 - val_loss: 0.0486 - val_accuracy: 0.7237
# Epoch 212/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0562 - accuracy: 0.7024 - val_loss: 0.0490 - val_accuracy: 0.7047
# Epoch 213/350
# 52/52 [==============================] - 4s 74ms/step - loss: 0.0563 - accuracy: 0.7052 - val_loss: 0.0485 - val_accuracy: 0.7135
# Epoch 214/350
# 52/52 [==============================] - 4s 75ms/step - loss: 0.0566 - accuracy: 0.7048 - val_loss: 0.0509 - val_accuracy: 0.6986
# Epoch 215/350
# 52/52 [==============================] - 4s 72ms/step - loss: 0.0561 - accuracy: 0.7062 - val_loss: 0.0482 - val_accuracy: 0.7149
# Epoch 216/350
# 52/52 [==============================] - 4s 74ms/step - loss: 0.0559 - accuracy: 0.7066 - val_loss: 0.0484 - val_accuracy: 0.7135
# Epoch 217/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0548 - accuracy: 0.7113 - val_loss: 0.0477 - val_accuracy: 0.7088
# Epoch 218/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0553 - accuracy: 0.7120 - val_loss: 0.0480 - val_accuracy: 0.7203
# Epoch 219/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0566 - accuracy: 0.7033 - val_loss: 0.0482 - val_accuracy: 0.7155
# Epoch 220/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0551 - accuracy: 0.7125 - val_loss: 0.0487 - val_accuracy: 0.7135
# Epoch 221/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0554 - accuracy: 0.7134 - val_loss: 0.0473 - val_accuracy: 0.7155
# Epoch 222/350
# 52/52 [==============================] - 4s 74ms/step - loss: 0.0558 - accuracy: 0.7054 - val_loss: 0.0508 - val_accuracy: 0.6999
# Epoch 223/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0555 - accuracy: 0.7117 - val_loss: 0.0479 - val_accuracy: 0.7169
# Epoch 224/350
# 52/52 [==============================] - 4s 74ms/step - loss: 0.0549 - accuracy: 0.7134 - val_loss: 0.0474 - val_accuracy: 0.7244
# Epoch 225/350
# 52/52 [==============================] - 4s 74ms/step - loss: 0.0545 - accuracy: 0.7141 - val_loss: 0.0479 - val_accuracy: 0.7244
# Epoch 226/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0558 - accuracy: 0.7096 - val_loss: 0.0490 - val_accuracy: 0.7135
# Epoch 227/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0536 - accuracy: 0.7242 - val_loss: 0.0491 - val_accuracy: 0.7210
# Epoch 228/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0549 - accuracy: 0.7168 - val_loss: 0.0458 - val_accuracy: 0.7366
# Epoch 229/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0547 - accuracy: 0.7156 - val_loss: 0.0476 - val_accuracy: 0.7251
# Epoch 230/350
# 52/52 [==============================] - 4s 75ms/step - loss: 0.0551 - accuracy: 0.7132 - val_loss: 0.0486 - val_accuracy: 0.7264
# Epoch 231/350
# 52/52 [==============================] - 4s 72ms/step - loss: 0.0553 - accuracy: 0.7127 - val_loss: 0.0465 - val_accuracy: 0.7257
# Epoch 232/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0553 - accuracy: 0.7123 - val_loss: 0.0460 - val_accuracy: 0.7230
# Epoch 233/350
# 52/52 [==============================] - 4s 72ms/step - loss: 0.0545 - accuracy: 0.7167 - val_loss: 0.0473 - val_accuracy: 0.7230
# Epoch 234/350
# 52/52 [==============================] - 4s 72ms/step - loss: 0.0540 - accuracy: 0.7191 - val_loss: 0.0471 - val_accuracy: 0.7169
# Epoch 235/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0532 - accuracy: 0.7220 - val_loss: 0.0488 - val_accuracy: 0.7251
# Epoch 236/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0540 - accuracy: 0.7223 - val_loss: 0.0479 - val_accuracy: 0.7298
# Epoch 237/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0536 - accuracy: 0.7202 - val_loss: 0.0465 - val_accuracy: 0.7434
# Epoch 238/350
# 52/52 [==============================] - 4s 75ms/step - loss: 0.0534 - accuracy: 0.7226 - val_loss: 0.0463 - val_accuracy: 0.7312
# Epoch 239/350
# 52/52 [==============================] - 4s 74ms/step - loss: 0.0535 - accuracy: 0.7255 - val_loss: 0.0463 - val_accuracy: 0.7230
# Epoch 240/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0533 - accuracy: 0.7246 - val_loss: 0.0477 - val_accuracy: 0.7203
# Epoch 241/350
# 52/52 [==============================] - 4s 74ms/step - loss: 0.0530 - accuracy: 0.7296 - val_loss: 0.0474 - val_accuracy: 0.7257
# Epoch 242/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0533 - accuracy: 0.7212 - val_loss: 0.0478 - val_accuracy: 0.7244
# Epoch 243/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0534 - accuracy: 0.7231 - val_loss: 0.0482 - val_accuracy: 0.7230
# Epoch 244/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0527 - accuracy: 0.7244 - val_loss: 0.0469 - val_accuracy: 0.7244
# Epoch 245/350
# 52/52 [==============================] - 4s 74ms/step - loss: 0.0528 - accuracy: 0.7292 - val_loss: 0.0474 - val_accuracy: 0.7210
# Epoch 246/350
# 52/52 [==============================] - 4s 75ms/step - loss: 0.0530 - accuracy: 0.7298 - val_loss: 0.0484 - val_accuracy: 0.7244
# Epoch 247/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0521 - accuracy: 0.7308 - val_loss: 0.0457 - val_accuracy: 0.7230
# Epoch 248/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0524 - accuracy: 0.7283 - val_loss: 0.0468 - val_accuracy: 0.7217
# Epoch 249/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0524 - accuracy: 0.7304 - val_loss: 0.0450 - val_accuracy: 0.7339
# Epoch 250/350
# 52/52 [==============================] - 4s 72ms/step - loss: 0.0533 - accuracy: 0.7242 - val_loss: 0.0472 - val_accuracy: 0.7298
# Epoch 251/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0526 - accuracy: 0.7307 - val_loss: 0.0446 - val_accuracy: 0.7244
# Epoch 252/350
# 52/52 [==============================] - 4s 72ms/step - loss: 0.0525 - accuracy: 0.7261 - val_loss: 0.0454 - val_accuracy: 0.7413
# Epoch 253/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0522 - accuracy: 0.7325 - val_loss: 0.0486 - val_accuracy: 0.7210
# Epoch 254/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0522 - accuracy: 0.7287 - val_loss: 0.0464 - val_accuracy: 0.7264
# Epoch 255/350
# 52/52 [==============================] - 4s 75ms/step - loss: 0.0523 - accuracy: 0.7321 - val_loss: 0.0480 - val_accuracy: 0.7318
# Epoch 256/350
# 52/52 [==============================] - 4s 74ms/step - loss: 0.0523 - accuracy: 0.7327 - val_loss: 0.0442 - val_accuracy: 0.7441
# Epoch 257/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0515 - accuracy: 0.7366 - val_loss: 0.0461 - val_accuracy: 0.7251
# Epoch 258/350
# 52/52 [==============================] - 4s 72ms/step - loss: 0.0518 - accuracy: 0.7361 - val_loss: 0.0463 - val_accuracy: 0.7312
# Epoch 259/350
# 52/52 [==============================] - 4s 74ms/step - loss: 0.0524 - accuracy: 0.7280 - val_loss: 0.0461 - val_accuracy: 0.7271
# Epoch 260/350
# 52/52 [==============================] - 4s 74ms/step - loss: 0.0511 - accuracy: 0.7367 - val_loss: 0.0482 - val_accuracy: 0.7244
# Epoch 261/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0521 - accuracy: 0.7338 - val_loss: 0.0464 - val_accuracy: 0.7291
# Epoch 262/350
# 52/52 [==============================] - 4s 72ms/step - loss: 0.0515 - accuracy: 0.7336 - val_loss: 0.0464 - val_accuracy: 0.7332
# Epoch 263/350
# 52/52 [==============================] - 4s 74ms/step - loss: 0.0514 - accuracy: 0.7344 - val_loss: 0.0457 - val_accuracy: 0.7278
# Epoch 264/350
# 52/52 [==============================] - 4s 74ms/step - loss: 0.0513 - accuracy: 0.7409 - val_loss: 0.0460 - val_accuracy: 0.7407
# Epoch 265/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0519 - accuracy: 0.7354 - val_loss: 0.0461 - val_accuracy: 0.7298
# Epoch 266/350
# 52/52 [==============================] - 4s 72ms/step - loss: 0.0511 - accuracy: 0.7427 - val_loss: 0.0459 - val_accuracy: 0.7434
# Epoch 267/350
# 52/52 [==============================] - 4s 74ms/step - loss: 0.0510 - accuracy: 0.7389 - val_loss: 0.0481 - val_accuracy: 0.7325
# Epoch 268/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0509 - accuracy: 0.7407 - val_loss: 0.0447 - val_accuracy: 0.7386
# Epoch 269/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0506 - accuracy: 0.7425 - val_loss: 0.0445 - val_accuracy: 0.7454
# Epoch 270/350
# 52/52 [==============================] - 4s 72ms/step - loss: 0.0507 - accuracy: 0.7405 - val_loss: 0.0452 - val_accuracy: 0.7339
# Epoch 271/350
# 52/52 [==============================] - 4s 76ms/step - loss: 0.0508 - accuracy: 0.7393 - val_loss: 0.0446 - val_accuracy: 0.7434
# Epoch 272/350
# 52/52 [==============================] - 4s 74ms/step - loss: 0.0504 - accuracy: 0.7423 - val_loss: 0.0454 - val_accuracy: 0.7339
# Epoch 273/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0505 - accuracy: 0.7412 - val_loss: 0.0451 - val_accuracy: 0.7441
# Epoch 274/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0506 - accuracy: 0.7383 - val_loss: 0.0449 - val_accuracy: 0.7427
# Epoch 275/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0504 - accuracy: 0.7477 - val_loss: 0.0460 - val_accuracy: 0.7400
# Epoch 276/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0506 - accuracy: 0.7418 - val_loss: 0.0441 - val_accuracy: 0.7386
# Epoch 277/350
# 52/52 [==============================] - 4s 74ms/step - loss: 0.0502 - accuracy: 0.7434 - val_loss: 0.0447 - val_accuracy: 0.7407
# Epoch 278/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0513 - accuracy: 0.7393 - val_loss: 0.0465 - val_accuracy: 0.7332
# Epoch 279/350
# 52/52 [==============================] - 4s 74ms/step - loss: 0.0522 - accuracy: 0.7340 - val_loss: 0.0446 - val_accuracy: 0.7386
# Epoch 280/350
# 52/52 [==============================] - 4s 74ms/step - loss: 0.0503 - accuracy: 0.7427 - val_loss: 0.0467 - val_accuracy: 0.7312
# Epoch 281/350
# 52/52 [==============================] - 4s 74ms/step - loss: 0.0498 - accuracy: 0.7468 - val_loss: 0.0458 - val_accuracy: 0.7359
# Epoch 282/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0503 - accuracy: 0.7461 - val_loss: 0.0442 - val_accuracy: 0.7413
# Epoch 283/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0500 - accuracy: 0.7529 - val_loss: 0.0471 - val_accuracy: 0.7332
# Epoch 284/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0498 - accuracy: 0.7438 - val_loss: 0.0457 - val_accuracy: 0.7332
# Epoch 285/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0498 - accuracy: 0.7483 - val_loss: 0.0456 - val_accuracy: 0.7400
# Epoch 286/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0499 - accuracy: 0.7430 - val_loss: 0.0452 - val_accuracy: 0.7427
# Epoch 287/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0500 - accuracy: 0.7425 - val_loss: 0.0462 - val_accuracy: 0.7441
# Epoch 288/350
# 52/52 [==============================] - 4s 76ms/step - loss: 0.0496 - accuracy: 0.7450 - val_loss: 0.0447 - val_accuracy: 0.7407
# Epoch 289/350
# 52/52 [==============================] - 4s 74ms/step - loss: 0.0501 - accuracy: 0.7414 - val_loss: 0.0434 - val_accuracy: 0.7495
# Epoch 291/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0495 - accuracy: 0.7495 - val_loss: 0.0462 - val_accuracy: 0.7284
# Epoch 292/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0505 - accuracy: 0.7455 - val_loss: 0.0447 - val_accuracy: 0.7407
# Epoch 293/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0497 - accuracy: 0.7485 - val_loss: 0.0432 - val_accuracy: 0.7373
# Epoch 294/350
# 52/52 [==============================] - 4s 72ms/step - loss: 0.0493 - accuracy: 0.7500 - val_loss: 0.0445 - val_accuracy: 0.7386
# Epoch 295/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0491 - accuracy: 0.7519 - val_loss: 0.0443 - val_accuracy: 0.7407
# Epoch 296/350
# 52/52 [==============================] - 4s 76ms/step - loss: 0.0489 - accuracy: 0.7530 - val_loss: 0.0448 - val_accuracy: 0.7373
# Epoch 297/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0491 - accuracy: 0.7510 - val_loss: 0.0429 - val_accuracy: 0.7420
# Epoch 298/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0496 - accuracy: 0.7468 - val_loss: 0.0445 - val_accuracy: 0.7420
# Epoch 299/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0493 - accuracy: 0.7528 - val_loss: 0.0449 - val_accuracy: 0.7427
# Epoch 300/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0487 - accuracy: 0.7542 - val_loss: 0.0438 - val_accuracy: 0.7468
# Epoch 301/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0492 - accuracy: 0.7481 - val_loss: 0.0461 - val_accuracy: 0.7379
# Epoch 302/350
# 52/52 [==============================] - 4s 72ms/step - loss: 0.0490 - accuracy: 0.7536 - val_loss: 0.0444 - val_accuracy: 0.7346
# Epoch 303/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0487 - accuracy: 0.7511 - val_loss: 0.0450 - val_accuracy: 0.7447
# Epoch 304/350
# 52/52 [==============================] - 4s 75ms/step - loss: 0.0492 - accuracy: 0.7515 - val_loss: 0.0460 - val_accuracy: 0.7230
# Epoch 305/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0496 - accuracy: 0.7485 - val_loss: 0.0454 - val_accuracy: 0.7441
# Epoch 306/350
# 52/52 [==============================] - 4s 74ms/step - loss: 0.0485 - accuracy: 0.7572 - val_loss: 0.0454 - val_accuracy: 0.7610
# Epoch 307/350
# 52/52 [==============================] - 4s 74ms/step - loss: 0.0486 - accuracy: 0.7559 - val_loss: 0.0439 - val_accuracy: 0.7468
# Epoch 308/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0487 - accuracy: 0.7542 - val_loss: 0.0440 - val_accuracy: 0.7468
# Epoch 309/350
# 52/52 [==============================] - 4s 74ms/step - loss: 0.0487 - accuracy: 0.7512 - val_loss: 0.0426 - val_accuracy: 0.7583
# Epoch 310/350
# 52/52 [==============================] - 4s 72ms/step - loss: 0.0487 - accuracy: 0.7520 - val_loss: 0.0444 - val_accuracy: 0.7400
# Epoch 311/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0486 - accuracy: 0.7527 - val_loss: 0.0434 - val_accuracy: 0.7413
# Epoch 312/350
# 52/52 [==============================] - 4s 74ms/step - loss: 0.0483 - accuracy: 0.7550 - val_loss: 0.0436 - val_accuracy: 0.7468
# Epoch 313/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0484 - accuracy: 0.7555 - val_loss: 0.0437 - val_accuracy: 0.7529
# Epoch 314/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0482 - accuracy: 0.7580 - val_loss: 0.0448 - val_accuracy: 0.7346
# Epoch 315/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0484 - accuracy: 0.7575 - val_loss: 0.0423 - val_accuracy: 0.7563
# Epoch 316/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0488 - accuracy: 0.7525 - val_loss: 0.0447 - val_accuracy: 0.7468
# Epoch 317/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0475 - accuracy: 0.7621 - val_loss: 0.0466 - val_accuracy: 0.7339
# Epoch 318/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0478 - accuracy: 0.7590 - val_loss: 0.0442 - val_accuracy: 0.7508
# Epoch 319/350
# 52/52 [==============================] - 4s 72ms/step - loss: 0.0479 - accuracy: 0.7567 - val_loss: 0.0434 - val_accuracy: 0.7481
# Epoch 320/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0476 - accuracy: 0.7572 - val_loss: 0.0437 - val_accuracy: 0.7522
# Epoch 321/350
# 52/52 [==============================] - 4s 74ms/step - loss: 0.0480 - accuracy: 0.7612 - val_loss: 0.0455 - val_accuracy: 0.7379
# Epoch 322/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0498 - accuracy: 0.7455 - val_loss: 0.0444 - val_accuracy: 0.7447
# Epoch 323/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0487 - accuracy: 0.7541 - val_loss: 0.0465 - val_accuracy: 0.7291
# Epoch 324/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0488 - accuracy: 0.7520 - val_loss: 0.0435 - val_accuracy: 0.7637
# Epoch 325/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0483 - accuracy: 0.7577 - val_loss: 0.0430 - val_accuracy: 0.7454
# Epoch 326/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0476 - accuracy: 0.7596 - val_loss: 0.0442 - val_accuracy: 0.7468
# Epoch 327/350
# 52/52 [==============================] - 4s 72ms/step - loss: 0.0474 - accuracy: 0.7644 - val_loss: 0.0430 - val_accuracy: 0.7604
# Epoch 328/350
# 52/52 [==============================] - 4s 72ms/step - loss: 0.0469 - accuracy: 0.7646 - val_loss: 0.0454 - val_accuracy: 0.7407
# Epoch 329/350
# 52/52 [==============================] - 4s 74ms/step - loss: 0.0474 - accuracy: 0.7630 - val_loss: 0.0439 - val_accuracy: 0.7508
# Epoch 330/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0468 - accuracy: 0.7645 - val_loss: 0.0443 - val_accuracy: 0.7468
# Epoch 331/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0474 - accuracy: 0.7592 - val_loss: 0.0448 - val_accuracy: 0.7386
# Epoch 332/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0470 - accuracy: 0.7621 - val_loss: 0.0439 - val_accuracy: 0.7468
# Epoch 333/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0471 - accuracy: 0.7630 - val_loss: 0.0424 - val_accuracy: 0.7515
# Epoch 334/350
# 52/52 [==============================] - 4s 72ms/step - loss: 0.0468 - accuracy: 0.7636 - val_loss: 0.0427 - val_accuracy: 0.7549
# Epoch 335/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0473 - accuracy: 0.7590 - val_loss: 0.0448 - val_accuracy: 0.7379
# Epoch 336/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0470 - accuracy: 0.7618 - val_loss: 0.0431 - val_accuracy: 0.7556
# Epoch 337/350
# 52/52 [==============================] - 4s 75ms/step - loss: 0.0467 - accuracy: 0.7651 - val_loss: 0.0426 - val_accuracy: 0.7549
# Epoch 338/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0465 - accuracy: 0.7662 - val_loss: 0.0414 - val_accuracy: 0.7556
# Epoch 339/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0472 - accuracy: 0.7664 - val_loss: 0.0432 - val_accuracy: 0.7604
# Epoch 340/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0473 - accuracy: 0.7596 - val_loss: 0.0456 - val_accuracy: 0.7352
# Epoch 341/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0470 - accuracy: 0.7636 - val_loss: 0.0435 - val_accuracy: 0.7447
# Epoch 342/350
# 52/52 [==============================] - 4s 72ms/step - loss: 0.0466 - accuracy: 0.7649 - val_loss: 0.0445 - val_accuracy: 0.7400
# Epoch 343/350
# 52/52 [==============================] - 4s 72ms/step - loss: 0.0472 - accuracy: 0.7581 - val_loss: 0.0428 - val_accuracy: 0.7447
# Epoch 344/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0460 - accuracy: 0.7670 - val_loss: 0.0438 - val_accuracy: 0.7522
# Epoch 345/350
# 52/52 [==============================] - 4s 74ms/step - loss: 0.0467 - accuracy: 0.7642 - val_loss: 0.0428 - val_accuracy: 0.7549
# Epoch 346/350
# 52/52 [==============================] - 4s 74ms/step - loss: 0.0462 - accuracy: 0.7695 - val_loss: 0.0433 - val_accuracy: 0.7393
# Epoch 347/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0461 - accuracy: 0.7704 - val_loss: 0.0429 - val_accuracy: 0.7447
# Epoch 348/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0465 - accuracy: 0.7673 - val_loss: 0.0417 - val_accuracy: 0.7495
# Epoch 349/350
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0459 - accuracy: 0.7683 - val_loss: 0.0453 - val_accuracy: 0.7386
# Epoch 350/350
# 52/52 [==============================] - 4s 72ms/step - loss: 0.0617 - accuracy: 0.6650 - val_loss: 0.0454 - val_accuracy: 0.7332

# %%
epochs = [i for i in range(350)]
fig , ax = plt.subplots(1,2)
train_acc = history.history['accuracy']
train_loss = history.history['loss']
val_acc = history.history['val_accuracy']
val_loss = history.history['val_loss']
fig.set_size_inches(40,8)

ax[0].plot(epochs , train_acc , 'go-' , label = 'Training Accuracy')
ax[0].plot(epochs , val_acc , 'ro-' , label = 'Validation Accuracy')
ax[0].set_title('Training & Validation Accuracy')
ax[0].legend()
ax[0].set_xlabel("Epochs")
ax[0].set_ylabel("Accuracy")

ax[1].plot(epochs , train_loss , 'g-o' , label = 'Training Loss')
ax[1].plot(epochs , val_loss , 'r-o' , label = 'Validation Loss')
ax[1].set_title('Testing Accuracy & Loss')
ax[1].legend()
ax[1].set_xlabel("Epochs")
ax[1].set_ylabel("Training & Validation Loss")
plt.show()

# %%
test_y=np.argmax(test_y, axis=1)

# %%
y_pred=vit.predict(test_x)
y_pred=np.argmax(y_pred, axis=1)
# Out:
# 116/116 [==============================] - 3s 17ms/step

# %%
from sklearn.metrics import classification_report, confusion_matrix
print(confusion_matrix(test_y,y_pred))
print(classification_report(test_y,y_pred))
# Out:
# [[430   0   0   0   0   0   0   0]
#  [  4 476   0   0   0   0   0   0]
#  [ 32   5 216  14   7 134   5  25]
#  [  0   0   0 432   0   0   0   2]
#  [  2   0   8   0 161  10 289   0]
#  [ 41  20 108  56   7 291   7  56]
#  [  0   0   0   0  14   0 400   0]
#  [ 25  10  40  13   5  69   3 265]]
#               precision    recall  f1-score   support
#
#            0       0.81      1.00      0.89       430
#            1       0.93      0.99      0.96       480
#            2       0.58      0.49      0.53       438
#            3       0.84      1.00      0.91       434
#            4       0.83      0.34      0.48       470
#            5       0.58      0.50      0.53       586
#            6       0.57      0.97      0.72       414
#            7       0.76      0.62      0.68       430
#
#     accuracy                           0.73      3682
#    macro avg       0.74      0.74      0.71      3682
# weighted avg       0.73      0.73      0.71      3682

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay
cm_LR=confusion_matrix(test_y, y_pred)
cmd = ConfusionMatrixDisplay(cm_LR, display_labels=['abnormalities', 'Diabetes', 'Hypertension', 'Glaucoma', 'Normal', 'Pathological Myopia', 'Age related Macular Degeneration', 'Cataract'])
#cmd = ConfusionMatrixDisplay(cm, display_labels=reversed_class_names)
#cmd.plot(cmap=plt.cm.Blues, values_format=".4g")  # You can customize the colormap and format

cmd.plot()
plt.title('Confusion Matrix')
# Out:
# Text(0.5, 1.0, 'Confusion Matrix')

# %%
print(create_vit_classifier)
# Out:
# <function create_vit_classifier at 0x7b2c2840bc70>
